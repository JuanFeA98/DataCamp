# %% [markdown]
# ## **LIBRERIAS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = False

# %% [markdown]
# ## **GRÁFICOS**

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# ### **Subplots - Columnas**

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='smoker')

plt.show()

# %% [markdown]
# ### **Subplots - Filas**

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', row='smoker')

plt.show()

# %% [markdown]
# ### **Subplots - Columnas y Filas**

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='smoker', row='time')

plt.show()

# %% [markdown]
# ### **Subplots - Columnas agrupadas**

# %%
sns.relplot(
    x='total_bill', 
    y='tip', 
    data=tips, 
    kind='scatter', 
    col='day', 
    col_wrap=2,
    col_order=['Thur', 'Fri', 'Sat', 'Sun'],
)

plt.show()

# %% [markdown]
# ### **Customizing Scatterplots**

# %%
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='scatter',
    size='size',
    hue='smoker',
    style='smoker',
    alpha=0.9,
)

plt.show()

# %% [markdown]
# ### **Line plots**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv')
df = df[df['Country'].isin(['Colombia', 'Spain', 'Italy', 'France', 'Germany'])]
df['Date'] = pd.to_datetime(df['Date'])
df = df[df['Date'].dt.year == 2021]

# %%
# Set the style like default

sns.relplot(
    data=df,
    x='Date',
    y='Confirmed',
    kind='line',
    hue='Country',
    style='Country'
)

plt.show()
