# %% [markdown]
# ## **Librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = False

# %% [markdown]
# ## **Gráficos**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/mpg_ggplot2.csv')

# %% [markdown]
# ### **1. Cambiando el color del fondo**

# %%
# Puede tomar los siguientes valores: "white", "dark", "whitegrid", "darkgrid", "ticks"
sns.set_style('darkgrid')

sns.catplot(
    data=df,
    x='cyl',
    y='cty',
    kind='box',
)

plt.show()

# %% [markdown]
# ### **2. Cambiando la paleta**

# %%
sns.set_style('darkgrid')
sns.set_palette('RdBu')

sns.catplot(
    data=df,
    x='cyl',
    y='cty',
    kind='bar',
    ci=None
)

plt.show()

# %%
sns.set_style('darkgrid')
sns.set_palette('Blues_r')

sns.catplot(
    data=df,
    x='cyl',
    y='cty',
    kind='bar',
    ci=None
)

plt.show()

# %% [markdown]
# #### **Usar una paleta personalizada**

# %%
custom_palette = ['#98abc5', '#8a89a6', '#7b6888', '#6b486b']

sns.set_style('darkgrid')
sns.set_palette(custom_palette)

sns.catplot(
    data=df,
    x='cyl',
    y='cty',
    kind='bar',
    ci=None
)

plt.show()

# %% [markdown]
# ### **3. Cambiando la escala**

# %%
sns.set_style('darkgrid')
sns.set_palette('Blues_r')

# Puede tomar los siguientes valores: 'paper', 'notebook', 'talk', 'poster'
sns.set_context('notebook')

sns.catplot(
    data=df,
    x='cyl',
    y='cty',
    kind='bar',
    ci=None
)

plt.show()

# %% [markdown]
# ### **4. Agregando titulos**

# %%
df = pd.read_csv('Datos/countries-of-the-world.csv')

# %%
df['Birthrate'] = df['Birthrate'].str.replace(',', '.')
df['Birthrate'] = df['Birthrate'].apply(lambda x: float(x))

# %%
g = sns.scatterplot(
    data=df, 
    x='Population',
    y='GDP ($ per capita)', 
    )

g.set_title('Titulo', y=1.02)

plt.show()

# %%
df['Region'] = df['Region'].apply(lambda x: x.strip())

# %%
g = sns.catplot(
    x='Region',
    y='Birthrate',
    data=df,
    kind='box',
)

g.fig.suptitle('New title', y=1.03)

g.set(
    xlabel='Region',
    ylabel='Birthdate'
)

plt.xticks(rotation=90)

plt.show()
