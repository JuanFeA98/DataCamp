# %% [markdown]
# ## **Librerias**

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = False

# %%
from datetime import datetime, timedelta
import winsound

# %% [markdown]
# ## **Datos**

# %%
df = pd.read_csv('https://assets.datacamp.com/production/repositories/3581/datasets/779033fb8fb5021aee9ff46253980abcbc5851f3/baseball_stats.csv')

# %% [markdown]
# ### **Calculating with Percentage**

# %%
def calc_win_perc(wins, games_played):
    win_perc = wins/games_played
    return np.round(win_perc, 2)

# %%
# %%timeit
df['W_Rate'] = df.apply(lambda x: round(x['W']/x['G'], 2), axis=1)
# Out:
# 20.5 ms ± 1.49 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
win_perc_list = []

for i, row in df.iterrows():
    wins = row['W']
    games = row['G']
    
    win_perc = calc_win_perc(wins, games)
    win_perc_list.append(win_perc)
    
df['W_Rate'] = win_perc_list
# Out:
# 218 ms ± 49.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df
# Out:
#      Team League  Year   RS   RA  ...  RankPlayoffs    G   OOBP   OSLG  W_Rate
# 0     ARI     NL  2012  734  688  ...           NaN  162  0.317  0.415    0.50
# 1     ATL     NL  2012  700  600  ...           5.0  162  0.306  0.378    0.58
# 2     BAL     AL  2012  712  705  ...           4.0  162  0.315  0.403    0.57
# 3     BOS     AL  2012  734  806  ...           NaN  162  0.331  0.428    0.43
# 4     CHC     NL  2012  613  759  ...           NaN  162  0.335  0.424    0.38
# ...   ...    ...   ...  ...  ...  ...           ...  ...    ...    ...     ...
# 1227  PHI     NL  1962  705  759  ...           NaN  161    NaN    NaN    0.50
# 1228  PIT     NL  1962  706  626  ...           NaN  161    NaN    NaN    0.58
# 1229  SFG     NL  1962  878  690  ...           2.0  165    NaN    NaN    0.62
# 1230  STL     NL  1962  774  664  ...           NaN  163    NaN    NaN    0.52
# 1231  WSA     AL  1962  599  716  ...           NaN  162    NaN    NaN    0.37
#
# [1232 rows x 16 columns]

# %%
for row_tuple in df[['Team', 'W']].itertuples():
    print(row_tuple)
# Out:
# Pandas(Index=0, Team='ARI', W=81)
# Pandas(Index=1, Team='ATL', W=94)
# Pandas(Index=2, Team='BAL', W=93)
# Pandas(Index=3, Team='BOS', W=69)
# Pandas(Index=4, Team='CHC', W=61)
# Pandas(Index=5, Team='CHW', W=85)
# Pandas(Index=6, Team='CIN', W=97)
# Pandas(Index=7, Team='CLE', W=68)
# Pandas(Index=8, Team='COL', W=64)
# Pandas(Index=9, Team='DET', W=88)
# Pandas(Index=10, Team='HOU', W=55)
# Pandas(Index=11, Team='KCR', W=72)
# Pandas(Index=12, Team='LAA', W=89)
# Pandas(Index=13, Team='LAD', W=86)
# Pandas(Index=14, Team='MIA', W=69)
# Pandas(Index=15, Team='MIL', W=83)
# Pandas(Index=16, Team='MIN', W=66)
# Pandas(Index=17, Team='NYM', W=74)
# Pandas(Index=18, Team='NYY', W=95)
# Pandas(Index=19, Team='OAK', W=94)
# Pandas(Index=20, Team='PHI', W=81)
# Pandas(Index=21, Team='PIT', W=79)
# Pandas(Index=22, Team='SDP', W=76)
# Pandas(Index=23, Team='SEA', W=75)
# Pandas(Index=24, Team='SFG', W=94)
# Pandas(Index=25, Team='STL', W=88)
# Pandas(Index=26, Team='TBR', W=90)
# Pandas(Index=27, Team='TEX', W=93)
# Pandas(Index=28, Team='TOR', W=73)
# Pandas(Index=29, Team='WSN', W=98)
# Pandas(Index=30, Team='ARI', W=94)
# Pandas(Index=31, Team='ATL', W=89)
# Pandas(Index=32, Team='BAL', W=69)
# Pandas(Index=33, Team='BOS', W=90)
# Pandas(Index=34, Team='CHC', W=71)
# Pandas(Index=35, Team='CHW', W=79)
# Pandas(Index=36, Team='CIN', W=79)
# Pandas(Index=37, Team='CLE', W=80)
# Pandas(Index=38, Team='COL', W=73)
# Pandas(Index=39, Team='DET', W=95)
# Pandas(Index=40, Team='FLA', W=72)
# Pandas(Index=41, Team='HOU', W=56)
# Pandas(Index=42, Team='KCR', W=71)
# Pandas(Index=43, Team='LAA', W=86)
# Pandas(Index=44, Team='LAD', W=82)
# Pandas(Index=45, Team='MIL', W=96)
# Pandas(Index=46, Team='MIN', W=63)
# Pandas(Index=47, Team='NYM', W=77)
# Pandas(Index=48, Team='NYY', W=97)
# Pandas(Index=49, Team='OAK', W=74)
# Pandas(Index=50, Team='PHI', W=102)
# Pandas(Index=51, Team='PIT', W=72)
# Pandas(Index=52, Team='SDP', W=71)
# Pandas(Index=53, Team='SEA', W=67)
# Pandas(Index=54, Team='SFG', W=86)
# Pandas(Index=55, Team='STL', W=90)
# Pandas(Index=56, Team='TBR', W=91)
# Pandas(Index=57, Team='TEX', W=96)
# Pandas(Index=58, Team='TOR', W=81)
# Pandas(Index=59, Team='WSN', W=80)
# Pandas(Index=60, Team='ARI', W=65)
# Pandas(Index=61, Team='ATL', W=91)
# Pandas(Index=62, Team='BAL', W=66)
# Pandas(Index=63, Team='BOS', W=89)
# Pandas(Index=64, Team='CHC', W=75)
# Pandas(Index=65, Team='CHW', W=88)
# Pandas(Index=66, Team='CIN', W=91)
# Pandas(Index=67, Team='CLE', W=69)
# Pandas(Index=68, Team='COL', W=83)
# Pandas(Index=69, Team='DET', W=81)
# Pandas(Index=70, Team='FLA', W=80)
# Pandas(Index=71, Team='HOU', W=76)
# Pandas(Index=72, Team='KCR', W=67)
# Pandas(Index=73, Team='LAA', W=80)
# Pandas(Index=74, Team='LAD', W=80)
# Pandas(Index=75, Team='MIL', W=77)
# Pandas(Index=76, Team='MIN', W=94)
# Pandas(Index=77, Team='NYM', W=79)
# Pandas(Index=78, Team='NYY', W=95)
# Pandas(Index=79, Team='OAK', W=81)
# Pandas(Index=80, Team='PHI', W=97)
# Pandas(Index=81, Team='PIT', W=57)
# Pandas(Index=82, Team='SDP', W=90)
# Pandas(Index=83, Team='SEA', W=61)
# Pandas(Index=84, Team='SFG', W=92)
# Pandas(Index=85, Team='STL', W=86)
# Pandas(Index=86, Team='TBR', W=96)
# Pandas(Index=87, Team='TEX', W=90)
# Pandas(Index=88, Team='TOR', W=85)
# Pandas(Index=89, Team='WSN', W=69)
# Pandas(Index=90, Team='ARI', W=70)
# Pandas(Index=91, Team='ATL', W=86)
# Pandas(Index=92, Team='BAL', W=64)
# Pandas(Index=93, Team='BOS', W=95)
# Pandas(Index=94, Team='CHC', W=83)
# Pandas(Index=95, Team='CHW', W=79)
# Pandas(Index=96, Team='CIN', W=78)
# Pandas(Index=97, Team='CLE', W=65)
# Pandas(Index=98, Team='COL', W=92)
# Pandas(Index=99, Team='DET', W=86)
# Pandas(Index=100, Team='FLA', W=87)
# Pandas(Index=101, Team='HOU', W=74)
# Pandas(Index=102, Team='KCR', W=65)
# Pandas(Index=103, Team='LAA', W=97)
# Pandas(Index=104, Team='LAD', W=95)
# Pandas(Index=105, Team='MIL', W=80)
# Pandas(Index=106, Team='MIN', W=87)
# Pandas(Index=107, Team='NYM', W=70)
# Pandas(Index=108, Team='NYY', W=103)
# Pandas(Index=109, Team='OAK', W=75)
# Pandas(Index=110, Team='PHI', W=93)
# Pandas(Index=111, Team='PIT', W=62)
# Pandas(Index=112, Team='SDP', W=75)
# Pandas(Index=113, Team='SEA', W=85)
# Pandas(Index=114, Team='SFG', W=88)
# Pandas(Index=115, Team='STL', W=91)
# Pandas(Index=116, Team='TBR', W=84)
# Pandas(Index=117, Team='TEX', W=87)
# Pandas(Index=118, Team='TOR', W=75)
# Pandas(Index=119, Team='WSN', W=59)
# Pandas(Index=120, Team='ARI', W=82)
# Pandas(Index=121, Team='ATL', W=72)
# Pandas(Index=122, Team='BAL', W=68)
# Pandas(Index=123, Team='BOS', W=95)
# Pandas(Index=124, Team='CHC', W=97)
# Pandas(Index=125, Team='CHW', W=89)
# Pandas(Index=126, Team='CIN', W=74)
# Pandas(Index=127, Team='CLE', W=81)
# Pandas(Index=128, Team='COL', W=74)
# Pandas(Index=129, Team='DET', W=74)
# Pandas(Index=130, Team='FLA', W=84)
# Pandas(Index=131, Team='HOU', W=86)
# Pandas(Index=132, Team='KCR', W=75)
# Pandas(Index=133, Team='LAA', W=100)
# Pandas(Index=134, Team='LAD', W=84)
# Pandas(Index=135, Team='MIL', W=90)
# Pandas(Index=136, Team='MIN', W=88)
# Pandas(Index=137, Team='NYM', W=89)
# Pandas(Index=138, Team='NYY', W=89)
# Pandas(Index=139, Team='OAK', W=75)
# Pandas(Index=140, Team='PHI', W=92)
# Pandas(Index=141, Team='PIT', W=67)
# Pandas(Index=142, Team='SDP', W=63)
# Pandas(Index=143, Team='SEA', W=61)
# Pandas(Index=144, Team='SFG', W=72)
# Pandas(Index=145, Team='STL', W=86)
# Pandas(Index=146, Team='TBR', W=97)
# Pandas(Index=147, Team='TEX', W=79)
# Pandas(Index=148, Team='TOR', W=86)
# Pandas(Index=149, Team='WSN', W=59)
# Pandas(Index=150, Team='ARI', W=90)
# Pandas(Index=151, Team='ATL', W=84)
# Pandas(Index=152, Team='BAL', W=69)
# Pandas(Index=153, Team='BOS', W=96)
# Pandas(Index=154, Team='CHC', W=85)
# Pandas(Index=155, Team='CHW', W=72)
# Pandas(Index=156, Team='CIN', W=72)
# Pandas(Index=157, Team='CLE', W=96)
# Pandas(Index=158, Team='COL', W=90)
# Pandas(Index=159, Team='DET', W=88)
# Pandas(Index=160, Team='FLA', W=71)
# Pandas(Index=161, Team='HOU', W=73)
# Pandas(Index=162, Team='KCR', W=69)
# Pandas(Index=163, Team='LAA', W=94)
# Pandas(Index=164, Team='LAD', W=82)
# Pandas(Index=165, Team='MIL', W=83)
# Pandas(Index=166, Team='MIN', W=79)
# Pandas(Index=167, Team='NYM', W=88)
# Pandas(Index=168, Team='NYY', W=94)
# Pandas(Index=169, Team='OAK', W=76)
# Pandas(Index=170, Team='PHI', W=89)
# Pandas(Index=171, Team='PIT', W=68)
# Pandas(Index=172, Team='SDP', W=89)
# Pandas(Index=173, Team='SEA', W=88)
# Pandas(Index=174, Team='SFG', W=71)
# Pandas(Index=175, Team='STL', W=78)
# Pandas(Index=176, Team='TBD', W=66)
# Pandas(Index=177, Team='TEX', W=75)
# Pandas(Index=178, Team='TOR', W=83)
# Pandas(Index=179, Team='WSN', W=73)
# Pandas(Index=180, Team='ARI', W=76)
# Pandas(Index=181, Team='ATL', W=79)
# Pandas(Index=182, Team='BAL', W=70)
# Pandas(Index=183, Team='BOS', W=86)
# Pandas(Index=184, Team='CHC', W=66)
# Pandas(Index=185, Team='CHW', W=90)
# Pandas(Index=186, Team='CIN', W=80)
# Pandas(Index=187, Team='CLE', W=78)
# Pandas(Index=188, Team='COL', W=76)
# Pandas(Index=189, Team='DET', W=95)
# Pandas(Index=190, Team='FLA', W=78)
# Pandas(Index=191, Team='HOU', W=82)
# Pandas(Index=192, Team='KCR', W=62)
# Pandas(Index=193, Team='LAA', W=89)
# Pandas(Index=194, Team='LAD', W=88)
# Pandas(Index=195, Team='MIL', W=75)
# Pandas(Index=196, Team='MIN', W=96)
# Pandas(Index=197, Team='NYM', W=97)
# Pandas(Index=198, Team='NYY', W=97)
# Pandas(Index=199, Team='OAK', W=93)
# Pandas(Index=200, Team='PHI', W=85)
# Pandas(Index=201, Team='PIT', W=67)
# Pandas(Index=202, Team='SDP', W=88)
# Pandas(Index=203, Team='SEA', W=78)
# Pandas(Index=204, Team='SFG', W=76)
# Pandas(Index=205, Team='STL', W=83)
# Pandas(Index=206, Team='TBD', W=61)
# Pandas(Index=207, Team='TEX', W=80)
# Pandas(Index=208, Team='TOR', W=87)
# Pandas(Index=209, Team='WSN', W=71)
# Pandas(Index=210, Team='ARI', W=77)
# Pandas(Index=211, Team='ATL', W=90)
# Pandas(Index=212, Team='BAL', W=74)
# Pandas(Index=213, Team='BOS', W=95)
# Pandas(Index=214, Team='CHC', W=79)
# Pandas(Index=215, Team='CHW', W=99)
# Pandas(Index=216, Team='CIN', W=73)
# Pandas(Index=217, Team='CLE', W=93)
# Pandas(Index=218, Team='COL', W=67)
# Pandas(Index=219, Team='DET', W=71)
# Pandas(Index=220, Team='FLA', W=83)
# Pandas(Index=221, Team='HOU', W=89)
# Pandas(Index=222, Team='KCR', W=56)
# Pandas(Index=223, Team='LAA', W=95)
# Pandas(Index=224, Team='LAD', W=71)
# Pandas(Index=225, Team='MIL', W=81)
# Pandas(Index=226, Team='MIN', W=83)
# Pandas(Index=227, Team='NYM', W=83)
# Pandas(Index=228, Team='NYY', W=95)
# Pandas(Index=229, Team='OAK', W=88)
# Pandas(Index=230, Team='PHI', W=88)
# Pandas(Index=231, Team='PIT', W=67)
# Pandas(Index=232, Team='SDP', W=82)
# Pandas(Index=233, Team='SEA', W=69)
# Pandas(Index=234, Team='SFG', W=75)
# Pandas(Index=235, Team='STL', W=100)
# Pandas(Index=236, Team='TBD', W=67)
# Pandas(Index=237, Team='TEX', W=79)
# Pandas(Index=238, Team='TOR', W=80)
# Pandas(Index=239, Team='WSN', W=81)
# Pandas(Index=240, Team='ANA', W=92)
# Pandas(Index=241, Team='ARI', W=51)
# Pandas(Index=242, Team='ATL', W=96)
# Pandas(Index=243, Team='BAL', W=78)
# Pandas(Index=244, Team='BOS', W=98)
# Pandas(Index=245, Team='CHC', W=89)
# Pandas(Index=246, Team='CHW', W=83)
# Pandas(Index=247, Team='CIN', W=76)
# Pandas(Index=248, Team='CLE', W=80)
# Pandas(Index=249, Team='COL', W=68)
# Pandas(Index=250, Team='DET', W=72)
# Pandas(Index=251, Team='FLA', W=83)
# Pandas(Index=252, Team='HOU', W=92)
# Pandas(Index=253, Team='KCR', W=58)
# Pandas(Index=254, Team='LAD', W=93)
# Pandas(Index=255, Team='MIL', W=67)
# Pandas(Index=256, Team='MIN', W=92)
# Pandas(Index=257, Team='MON', W=67)
# Pandas(Index=258, Team='NYM', W=71)
# Pandas(Index=259, Team='NYY', W=101)
# Pandas(Index=260, Team='OAK', W=91)
# Pandas(Index=261, Team='PHI', W=86)
# Pandas(Index=262, Team='PIT', W=72)
# Pandas(Index=263, Team='SDP', W=87)
# Pandas(Index=264, Team='SEA', W=63)
# Pandas(Index=265, Team='SFG', W=91)
# Pandas(Index=266, Team='STL', W=105)
# Pandas(Index=267, Team='TBD', W=70)
# Pandas(Index=268, Team='TEX', W=89)
# Pandas(Index=269, Team='TOR', W=67)
# Pandas(Index=270, Team='ANA', W=77)
# Pandas(Index=271, Team='ARI', W=84)
# Pandas(Index=272, Team='ATL', W=101)
# Pandas(Index=273, Team='BAL', W=71)
# Pandas(Index=274, Team='BOS', W=95)
# Pandas(Index=275, Team='CHC', W=88)
# Pandas(Index=276, Team='CHW', W=86)
# Pandas(Index=277, Team='CIN', W=69)
# Pandas(Index=278, Team='CLE', W=68)
# Pandas(Index=279, Team='COL', W=74)
# Pandas(Index=280, Team='DET', W=43)
# Pandas(Index=281, Team='FLA', W=91)
# Pandas(Index=282, Team='HOU', W=87)
# Pandas(Index=283, Team='KCR', W=83)
# Pandas(Index=284, Team='LAD', W=85)
# Pandas(Index=285, Team='MIL', W=68)
# Pandas(Index=286, Team='MIN', W=90)
# Pandas(Index=287, Team='MON', W=83)
# Pandas(Index=288, Team='NYM', W=66)
# Pandas(Index=289, Team='NYY', W=101)
# Pandas(Index=290, Team='OAK', W=96)
# Pandas(Index=291, Team='PHI', W=86)
# Pandas(Index=292, Team='PIT', W=75)
# Pandas(Index=293, Team='SDP', W=64)
# Pandas(Index=294, Team='SEA', W=93)
# Pandas(Index=295, Team='SFG', W=100)
# Pandas(Index=296, Team='STL', W=85)
# Pandas(Index=297, Team='TBD', W=63)
# Pandas(Index=298, Team='TEX', W=71)
# Pandas(Index=299, Team='TOR', W=86)
# Pandas(Index=300, Team='ANA', W=99)
# Pandas(Index=301, Team='ARI', W=98)
# Pandas(Index=302, Team='ATL', W=101)
# Pandas(Index=303, Team='BAL', W=67)
# Pandas(Index=304, Team='BOS', W=93)
# Pandas(Index=305, Team='CHC', W=67)
# Pandas(Index=306, Team='CHW', W=81)
# Pandas(Index=307, Team='CIN', W=78)
# Pandas(Index=308, Team='CLE', W=74)
# Pandas(Index=309, Team='COL', W=73)
# Pandas(Index=310, Team='DET', W=55)
# Pandas(Index=311, Team='FLA', W=79)
# Pandas(Index=312, Team='HOU', W=84)
# Pandas(Index=313, Team='KCR', W=62)
# Pandas(Index=314, Team='LAD', W=92)
# Pandas(Index=315, Team='MIL', W=56)
# Pandas(Index=316, Team='MIN', W=94)
# Pandas(Index=317, Team='MON', W=83)
# Pandas(Index=318, Team='NYM', W=75)
# Pandas(Index=319, Team='NYY', W=103)
# Pandas(Index=320, Team='OAK', W=103)
# Pandas(Index=321, Team='PHI', W=80)
# Pandas(Index=322, Team='PIT', W=72)
# Pandas(Index=323, Team='SDP', W=66)
# Pandas(Index=324, Team='SEA', W=93)
# Pandas(Index=325, Team='SFG', W=95)
# Pandas(Index=326, Team='STL', W=97)
# Pandas(Index=327, Team='TBD', W=55)
# Pandas(Index=328, Team='TEX', W=72)
# Pandas(Index=329, Team='TOR', W=78)
# Pandas(Index=330, Team='ANA', W=75)
# Pandas(Index=331, Team='ARI', W=92)
# Pandas(Index=332, Team='ATL', W=88)
# Pandas(Index=333, Team='BAL', W=63)
# Pandas(Index=334, Team='BOS', W=82)
# Pandas(Index=335, Team='CHC', W=88)
# Pandas(Index=336, Team='CHW', W=83)
# Pandas(Index=337, Team='CIN', W=66)
# Pandas(Index=338, Team='CLE', W=91)
# Pandas(Index=339, Team='COL', W=73)
# Pandas(Index=340, Team='DET', W=66)
# Pandas(Index=341, Team='FLA', W=76)
# Pandas(Index=342, Team='HOU', W=93)
# Pandas(Index=343, Team='KCR', W=65)
# Pandas(Index=344, Team='LAD', W=86)
# Pandas(Index=345, Team='MIL', W=68)
# Pandas(Index=346, Team='MIN', W=85)
# Pandas(Index=347, Team='MON', W=68)
# Pandas(Index=348, Team='NYM', W=82)
# Pandas(Index=349, Team='NYY', W=95)
# Pandas(Index=350, Team='OAK', W=102)
# Pandas(Index=351, Team='PHI', W=86)
# Pandas(Index=352, Team='PIT', W=62)
# Pandas(Index=353, Team='SDP', W=79)
# Pandas(Index=354, Team='SEA', W=116)
# Pandas(Index=355, Team='SFG', W=90)
# Pandas(Index=356, Team='STL', W=93)
# Pandas(Index=357, Team='TBD', W=62)
# Pandas(Index=358, Team='TEX', W=73)
# Pandas(Index=359, Team='TOR', W=80)
# Pandas(Index=360, Team='ANA', W=82)
# Pandas(Index=361, Team='ARI', W=85)
# Pandas(Index=362, Team='ATL', W=95)
# Pandas(Index=363, Team='BAL', W=74)
# Pandas(Index=364, Team='BOS', W=85)
# Pandas(Index=365, Team='CHC', W=65)
# Pandas(Index=366, Team='CHW', W=95)
# Pandas(Index=367, Team='CIN', W=85)
# Pandas(Index=368, Team='CLE', W=90)
# Pandas(Index=369, Team='COL', W=82)
# Pandas(Index=370, Team='DET', W=79)
# Pandas(Index=371, Team='FLA', W=79)
# Pandas(Index=372, Team='HOU', W=72)
# Pandas(Index=373, Team='KCR', W=77)
# Pandas(Index=374, Team='LAD', W=86)
# Pandas(Index=375, Team='MIL', W=73)
# Pandas(Index=376, Team='MIN', W=69)
# Pandas(Index=377, Team='MON', W=67)
# Pandas(Index=378, Team='NYM', W=94)
# Pandas(Index=379, Team='NYY', W=87)
# Pandas(Index=380, Team='OAK', W=91)
# Pandas(Index=381, Team='PHI', W=65)
# Pandas(Index=382, Team='PIT', W=69)
# Pandas(Index=383, Team='SDP', W=76)
# Pandas(Index=384, Team='SEA', W=91)
# Pandas(Index=385, Team='SFG', W=97)
# Pandas(Index=386, Team='STL', W=95)
# Pandas(Index=387, Team='TBD', W=69)
# Pandas(Index=388, Team='TEX', W=71)
# Pandas(Index=389, Team='TOR', W=83)
# Pandas(Index=390, Team='ANA', W=70)
# Pandas(Index=391, Team='ARI', W=100)
# Pandas(Index=392, Team='ATL', W=103)
# Pandas(Index=393, Team='BAL', W=78)
# Pandas(Index=394, Team='BOS', W=94)
# Pandas(Index=395, Team='CHC', W=67)
# Pandas(Index=396, Team='CHW', W=75)
# Pandas(Index=397, Team='CIN', W=96)
# Pandas(Index=398, Team='CLE', W=97)
# Pandas(Index=399, Team='COL', W=72)
# Pandas(Index=400, Team='DET', W=69)
# Pandas(Index=401, Team='FLA', W=64)
# Pandas(Index=402, Team='HOU', W=97)
# Pandas(Index=403, Team='KCR', W=64)
# Pandas(Index=404, Team='LAD', W=77)
# Pandas(Index=405, Team='MIL', W=74)
# Pandas(Index=406, Team='MIN', W=63)
# Pandas(Index=407, Team='MON', W=68)
# Pandas(Index=408, Team='NYM', W=97)
# Pandas(Index=409, Team='NYY', W=98)
# Pandas(Index=410, Team='OAK', W=87)
# Pandas(Index=411, Team='PHI', W=77)
# Pandas(Index=412, Team='PIT', W=78)
# Pandas(Index=413, Team='SDP', W=74)
# Pandas(Index=414, Team='SEA', W=79)
# Pandas(Index=415, Team='SFG', W=86)
# Pandas(Index=416, Team='STL', W=75)
# Pandas(Index=417, Team='TBD', W=69)
# Pandas(Index=418, Team='TEX', W=95)
# Pandas(Index=419, Team='TOR', W=84)
# Pandas(Index=420, Team='ANA', W=85)
# Pandas(Index=421, Team='ARI', W=65)
# Pandas(Index=422, Team='ATL', W=106)
# Pandas(Index=423, Team='BAL', W=79)
# Pandas(Index=424, Team='BOS', W=92)
# Pandas(Index=425, Team='CHC', W=90)
# Pandas(Index=426, Team='CHW', W=80)
# Pandas(Index=427, Team='CIN', W=77)
# Pandas(Index=428, Team='CLE', W=89)
# Pandas(Index=429, Team='COL', W=77)
# Pandas(Index=430, Team='DET', W=65)
# Pandas(Index=431, Team='FLA', W=54)
# Pandas(Index=432, Team='HOU', W=102)
# Pandas(Index=433, Team='KCR', W=72)
# Pandas(Index=434, Team='LAD', W=83)
# Pandas(Index=435, Team='MIL', W=74)
# Pandas(Index=436, Team='MIN', W=70)
# Pandas(Index=437, Team='MON', W=65)
# Pandas(Index=438, Team='NYM', W=88)
# Pandas(Index=439, Team='NYY', W=114)
# Pandas(Index=440, Team='OAK', W=74)
# Pandas(Index=441, Team='PHI', W=75)
# Pandas(Index=442, Team='PIT', W=69)
# Pandas(Index=443, Team='SDP', W=98)
# Pandas(Index=444, Team='SEA', W=76)
# Pandas(Index=445, Team='SFG', W=89)
# Pandas(Index=446, Team='STL', W=83)
# Pandas(Index=447, Team='TBD', W=63)
# Pandas(Index=448, Team='TEX', W=88)
# Pandas(Index=449, Team='TOR', W=88)
# Pandas(Index=450, Team='ANA', W=84)
# Pandas(Index=451, Team='ATL', W=101)
# Pandas(Index=452, Team='BAL', W=98)
# Pandas(Index=453, Team='BOS', W=78)
# Pandas(Index=454, Team='CHC', W=68)
# Pandas(Index=455, Team='CHW', W=80)
# Pandas(Index=456, Team='CIN', W=76)
# Pandas(Index=457, Team='CLE', W=86)
# Pandas(Index=458, Team='COL', W=83)
# Pandas(Index=459, Team='DET', W=79)
# Pandas(Index=460, Team='FLA', W=92)
# Pandas(Index=461, Team='HOU', W=84)
# Pandas(Index=462, Team='KCR', W=67)
# Pandas(Index=463, Team='LAD', W=88)
# Pandas(Index=464, Team='MIL', W=78)
# Pandas(Index=465, Team='MIN', W=68)
# Pandas(Index=466, Team='MON', W=78)
# Pandas(Index=467, Team='NYM', W=88)
# Pandas(Index=468, Team='NYY', W=96)
# Pandas(Index=469, Team='OAK', W=65)
# Pandas(Index=470, Team='PHI', W=68)
# Pandas(Index=471, Team='PIT', W=79)
# Pandas(Index=472, Team='SDP', W=76)
# Pandas(Index=473, Team='SEA', W=90)
# Pandas(Index=474, Team='SFG', W=90)
# Pandas(Index=475, Team='STL', W=73)
# Pandas(Index=476, Team='TEX', W=77)
# Pandas(Index=477, Team='TOR', W=76)
# Pandas(Index=478, Team='ATL', W=96)
# Pandas(Index=479, Team='BAL', W=88)
# Pandas(Index=480, Team='BOS', W=85)
# Pandas(Index=481, Team='CAL', W=70)
# Pandas(Index=482, Team='CHC', W=76)
# Pandas(Index=483, Team='CHW', W=85)
# Pandas(Index=484, Team='CIN', W=81)
# Pandas(Index=485, Team='CLE', W=99)
# Pandas(Index=486, Team='COL', W=83)
# Pandas(Index=487, Team='DET', W=53)
# Pandas(Index=488, Team='FLA', W=80)
# Pandas(Index=489, Team='HOU', W=82)
# Pandas(Index=490, Team='KCR', W=75)
# Pandas(Index=491, Team='LAD', W=90)
# Pandas(Index=492, Team='MIL', W=80)
# Pandas(Index=493, Team='MIN', W=78)
# Pandas(Index=494, Team='MON', W=88)
# Pandas(Index=495, Team='NYM', W=71)
# Pandas(Index=496, Team='NYY', W=92)
# Pandas(Index=497, Team='OAK', W=78)
# Pandas(Index=498, Team='PHI', W=67)
# Pandas(Index=499, Team='PIT', W=73)
# Pandas(Index=500, Team='SDP', W=91)
# Pandas(Index=501, Team='SEA', W=85)
# Pandas(Index=502, Team='SFG', W=68)
# Pandas(Index=503, Team='STL', W=88)
# Pandas(Index=504, Team='TEX', W=90)
# Pandas(Index=505, Team='TOR', W=74)
# Pandas(Index=506, Team='ATL', W=104)
# Pandas(Index=507, Team='BAL', W=85)
# Pandas(Index=508, Team='BOS', W=80)
# Pandas(Index=509, Team='CAL', W=71)
# Pandas(Index=510, Team='CHC', W=84)
# Pandas(Index=511, Team='CHW', W=94)
# Pandas(Index=512, Team='CIN', W=73)
# Pandas(Index=513, Team='CLE', W=76)
# Pandas(Index=514, Team='COL', W=67)
# Pandas(Index=515, Team='DET', W=85)
# Pandas(Index=516, Team='FLA', W=64)
# Pandas(Index=517, Team='HOU', W=85)
# Pandas(Index=518, Team='KCR', W=84)
# Pandas(Index=519, Team='LAD', W=81)
# Pandas(Index=520, Team='MIL', W=69)
# Pandas(Index=521, Team='MIN', W=71)
# Pandas(Index=522, Team='MON', W=94)
# Pandas(Index=523, Team='NYM', W=59)
# Pandas(Index=524, Team='NYY', W=88)
# Pandas(Index=525, Team='OAK', W=68)
# Pandas(Index=526, Team='PHI', W=97)
# Pandas(Index=527, Team='PIT', W=75)
# Pandas(Index=528, Team='SDP', W=61)
# Pandas(Index=529, Team='SEA', W=82)
# Pandas(Index=530, Team='SFG', W=103)
# Pandas(Index=531, Team='STL', W=87)
# Pandas(Index=532, Team='TEX', W=86)
# Pandas(Index=533, Team='TOR', W=95)
# Pandas(Index=534, Team='ATL', W=98)
# Pandas(Index=535, Team='BAL', W=89)
# Pandas(Index=536, Team='BOS', W=73)
# Pandas(Index=537, Team='CAL', W=72)
# Pandas(Index=538, Team='CHC', W=78)
# Pandas(Index=539, Team='CHW', W=86)
# Pandas(Index=540, Team='CIN', W=90)
# Pandas(Index=541, Team='CLE', W=76)
# Pandas(Index=542, Team='DET', W=75)
# Pandas(Index=543, Team='HOU', W=81)
# Pandas(Index=544, Team='KCR', W=72)
# Pandas(Index=545, Team='LAD', W=63)
# Pandas(Index=546, Team='MIL', W=92)
# Pandas(Index=547, Team='MIN', W=90)
# Pandas(Index=548, Team='MON', W=87)
# Pandas(Index=549, Team='NYM', W=72)
# Pandas(Index=550, Team='NYY', W=76)
# Pandas(Index=551, Team='OAK', W=96)
# Pandas(Index=552, Team='PHI', W=70)
# Pandas(Index=553, Team='PIT', W=96)
# Pandas(Index=554, Team='SDP', W=82)
# Pandas(Index=555, Team='SEA', W=64)
# Pandas(Index=556, Team='SFG', W=72)
# Pandas(Index=557, Team='STL', W=83)
# Pandas(Index=558, Team='TEX', W=77)
# Pandas(Index=559, Team='TOR', W=96)
# Pandas(Index=560, Team='ATL', W=94)
# Pandas(Index=561, Team='BAL', W=67)
# Pandas(Index=562, Team='BOS', W=84)
# Pandas(Index=563, Team='CAL', W=81)
# Pandas(Index=564, Team='CHC', W=77)
# Pandas(Index=565, Team='CHW', W=87)
# Pandas(Index=566, Team='CIN', W=74)
# Pandas(Index=567, Team='CLE', W=57)
# Pandas(Index=568, Team='DET', W=84)
# Pandas(Index=569, Team='HOU', W=65)
# Pandas(Index=570, Team='KCR', W=82)
# Pandas(Index=571, Team='LAD', W=93)
# Pandas(Index=572, Team='MIL', W=83)
# Pandas(Index=573, Team='MIN', W=95)
# Pandas(Index=574, Team='MON', W=71)
# Pandas(Index=575, Team='NYM', W=77)
# Pandas(Index=576, Team='NYY', W=71)
# Pandas(Index=577, Team='OAK', W=84)
# Pandas(Index=578, Team='PHI', W=78)
# Pandas(Index=579, Team='PIT', W=98)
# Pandas(Index=580, Team='SDP', W=84)
# Pandas(Index=581, Team='SEA', W=83)
# Pandas(Index=582, Team='SFG', W=75)
# Pandas(Index=583, Team='STL', W=84)
# Pandas(Index=584, Team='TEX', W=85)
# Pandas(Index=585, Team='TOR', W=91)
# Pandas(Index=586, Team='ATL', W=65)
# Pandas(Index=587, Team='BAL', W=76)
# Pandas(Index=588, Team='BOS', W=88)
# Pandas(Index=589, Team='CAL', W=80)
# Pandas(Index=590, Team='CHC', W=77)
# Pandas(Index=591, Team='CHW', W=94)
# Pandas(Index=592, Team='CIN', W=91)
# Pandas(Index=593, Team='CLE', W=77)
# Pandas(Index=594, Team='DET', W=79)
# Pandas(Index=595, Team='HOU', W=75)
# Pandas(Index=596, Team='KCR', W=75)
# Pandas(Index=597, Team='LAD', W=86)
# Pandas(Index=598, Team='MIL', W=74)
# Pandas(Index=599, Team='MIN', W=74)
# Pandas(Index=600, Team='MON', W=85)
# Pandas(Index=601, Team='NYM', W=91)
# Pandas(Index=602, Team='NYY', W=67)
# Pandas(Index=603, Team='OAK', W=103)
# Pandas(Index=604, Team='PHI', W=77)
# Pandas(Index=605, Team='PIT', W=95)
# Pandas(Index=606, Team='SDP', W=75)
# Pandas(Index=607, Team='SEA', W=77)
# Pandas(Index=608, Team='SFG', W=85)
# Pandas(Index=609, Team='STL', W=70)
# Pandas(Index=610, Team='TEX', W=83)
# Pandas(Index=611, Team='TOR', W=86)
# Pandas(Index=612, Team='ATL', W=63)
# Pandas(Index=613, Team='BAL', W=87)
# Pandas(Index=614, Team='BOS', W=83)
# Pandas(Index=615, Team='CAL', W=91)
# Pandas(Index=616, Team='CHC', W=93)
# Pandas(Index=617, Team='CHW', W=69)
# Pandas(Index=618, Team='CIN', W=75)
# Pandas(Index=619, Team='CLE', W=73)
# Pandas(Index=620, Team='DET', W=59)
# Pandas(Index=621, Team='HOU', W=86)
# Pandas(Index=622, Team='KCR', W=92)
# Pandas(Index=623, Team='LAD', W=77)
# Pandas(Index=624, Team='MIL', W=81)
# Pandas(Index=625, Team='MIN', W=80)
# Pandas(Index=626, Team='MON', W=81)
# Pandas(Index=627, Team='NYM', W=87)
# Pandas(Index=628, Team='NYY', W=74)
# Pandas(Index=629, Team='OAK', W=99)
# Pandas(Index=630, Team='PHI', W=67)
# Pandas(Index=631, Team='PIT', W=74)
# Pandas(Index=632, Team='SDP', W=89)
# Pandas(Index=633, Team='SEA', W=73)
# Pandas(Index=634, Team='SFG', W=92)
# Pandas(Index=635, Team='STL', W=86)
# Pandas(Index=636, Team='TEX', W=83)
# Pandas(Index=637, Team='TOR', W=89)
# Pandas(Index=638, Team='ATL', W=54)
# Pandas(Index=639, Team='BAL', W=54)
# Pandas(Index=640, Team='BOS', W=89)
# Pandas(Index=641, Team='CAL', W=75)
# Pandas(Index=642, Team='CHC', W=77)
# Pandas(Index=643, Team='CHW', W=71)
# Pandas(Index=644, Team='CIN', W=87)
# Pandas(Index=645, Team='CLE', W=78)
# Pandas(Index=646, Team='DET', W=88)
# Pandas(Index=647, Team='HOU', W=82)
# Pandas(Index=648, Team='KCR', W=84)
# Pandas(Index=649, Team='LAD', W=94)
# Pandas(Index=650, Team='MIL', W=87)
# Pandas(Index=651, Team='MIN', W=91)
# Pandas(Index=652, Team='MON', W=81)
# Pandas(Index=653, Team='NYM', W=100)
# Pandas(Index=654, Team='NYY', W=85)
# Pandas(Index=655, Team='OAK', W=104)
# Pandas(Index=656, Team='PHI', W=65)
# Pandas(Index=657, Team='PIT', W=85)
# Pandas(Index=658, Team='SDP', W=83)
# Pandas(Index=659, Team='SEA', W=68)
# Pandas(Index=660, Team='SFG', W=83)
# Pandas(Index=661, Team='STL', W=76)
# Pandas(Index=662, Team='TEX', W=70)
# Pandas(Index=663, Team='TOR', W=87)
# Pandas(Index=664, Team='ATL', W=69)
# Pandas(Index=665, Team='BAL', W=67)
# Pandas(Index=666, Team='BOS', W=78)
# Pandas(Index=667, Team='CAL', W=75)
# Pandas(Index=668, Team='CHC', W=76)
# Pandas(Index=669, Team='CHW', W=77)
# Pandas(Index=670, Team='CIN', W=84)
# Pandas(Index=671, Team='CLE', W=61)
# Pandas(Index=672, Team='DET', W=98)
# Pandas(Index=673, Team='HOU', W=76)
# Pandas(Index=674, Team='KCR', W=83)
# Pandas(Index=675, Team='LAD', W=73)
# Pandas(Index=676, Team='MIL', W=91)
# Pandas(Index=677, Team='MIN', W=85)
# Pandas(Index=678, Team='MON', W=91)
# Pandas(Index=679, Team='NYM', W=92)
# Pandas(Index=680, Team='NYY', W=89)
# Pandas(Index=681, Team='OAK', W=81)
# Pandas(Index=682, Team='PHI', W=80)
# Pandas(Index=683, Team='PIT', W=80)
# Pandas(Index=684, Team='SDP', W=65)
# Pandas(Index=685, Team='SEA', W=78)
# Pandas(Index=686, Team='SFG', W=90)
# Pandas(Index=687, Team='STL', W=95)
# Pandas(Index=688, Team='TEX', W=75)
# Pandas(Index=689, Team='TOR', W=96)
# Pandas(Index=690, Team='ATL', W=72)
# Pandas(Index=691, Team='BAL', W=73)
# Pandas(Index=692, Team='BOS', W=95)
# Pandas(Index=693, Team='CAL', W=92)
# Pandas(Index=694, Team='CHC', W=70)
# Pandas(Index=695, Team='CHW', W=72)
# Pandas(Index=696, Team='CIN', W=86)
# Pandas(Index=697, Team='CLE', W=84)
# Pandas(Index=698, Team='DET', W=87)
# Pandas(Index=699, Team='HOU', W=96)
# Pandas(Index=700, Team='KCR', W=76)
# Pandas(Index=701, Team='LAD', W=73)
# Pandas(Index=702, Team='MIL', W=77)
# Pandas(Index=703, Team='MIN', W=71)
# Pandas(Index=704, Team='MON', W=78)
# Pandas(Index=705, Team='NYM', W=108)
# Pandas(Index=706, Team='NYY', W=90)
# Pandas(Index=707, Team='OAK', W=76)
# Pandas(Index=708, Team='PHI', W=86)
# Pandas(Index=709, Team='PIT', W=64)
# Pandas(Index=710, Team='SDP', W=74)
# Pandas(Index=711, Team='SEA', W=67)
# Pandas(Index=712, Team='SFG', W=83)
# Pandas(Index=713, Team='STL', W=79)
# Pandas(Index=714, Team='TEX', W=87)
# Pandas(Index=715, Team='TOR', W=86)
# Pandas(Index=716, Team='ATL', W=66)
# Pandas(Index=717, Team='BAL', W=83)
# Pandas(Index=718, Team='BOS', W=81)
# Pandas(Index=719, Team='CAL', W=90)
# Pandas(Index=720, Team='CHC', W=77)
# Pandas(Index=721, Team='CHW', W=85)
# Pandas(Index=722, Team='CIN', W=89)
# Pandas(Index=723, Team='CLE', W=60)
# Pandas(Index=724, Team='DET', W=84)
# Pandas(Index=725, Team='HOU', W=83)
# Pandas(Index=726, Team='KCR', W=91)
# Pandas(Index=727, Team='LAD', W=95)
# Pandas(Index=728, Team='MIL', W=71)
# Pandas(Index=729, Team='MIN', W=77)
# Pandas(Index=730, Team='MON', W=84)
# Pandas(Index=731, Team='NYM', W=98)
# Pandas(Index=732, Team='NYY', W=97)
# Pandas(Index=733, Team='OAK', W=77)
# Pandas(Index=734, Team='PHI', W=75)
# Pandas(Index=735, Team='PIT', W=57)
# Pandas(Index=736, Team='SDP', W=83)
# Pandas(Index=737, Team='SEA', W=74)
# Pandas(Index=738, Team='SFG', W=62)
# Pandas(Index=739, Team='STL', W=101)
# Pandas(Index=740, Team='TEX', W=62)
# Pandas(Index=741, Team='TOR', W=99)
# Pandas(Index=742, Team='ATL', W=80)
# Pandas(Index=743, Team='BAL', W=85)
# Pandas(Index=744, Team='BOS', W=86)
# Pandas(Index=745, Team='CAL', W=81)
# Pandas(Index=746, Team='CHC', W=96)
# Pandas(Index=747, Team='CHW', W=74)
# Pandas(Index=748, Team='CIN', W=70)
# Pandas(Index=749, Team='CLE', W=75)
# Pandas(Index=750, Team='DET', W=104)
# Pandas(Index=751, Team='HOU', W=80)
# Pandas(Index=752, Team='KCR', W=84)
# Pandas(Index=753, Team='LAD', W=79)
# Pandas(Index=754, Team='MIL', W=67)
# Pandas(Index=755, Team='MIN', W=81)
# Pandas(Index=756, Team='MON', W=78)
# Pandas(Index=757, Team='NYM', W=90)
# Pandas(Index=758, Team='NYY', W=87)
# Pandas(Index=759, Team='OAK', W=77)
# Pandas(Index=760, Team='PHI', W=81)
# Pandas(Index=761, Team='PIT', W=75)
# Pandas(Index=762, Team='SDP', W=92)
# Pandas(Index=763, Team='SEA', W=74)
# Pandas(Index=764, Team='SFG', W=66)
# Pandas(Index=765, Team='STL', W=84)
# Pandas(Index=766, Team='TEX', W=69)
# Pandas(Index=767, Team='TOR', W=89)
# Pandas(Index=768, Team='ATL', W=88)
# Pandas(Index=769, Team='BAL', W=98)
# Pandas(Index=770, Team='BOS', W=78)
# Pandas(Index=771, Team='CAL', W=70)
# Pandas(Index=772, Team='CHC', W=71)
# Pandas(Index=773, Team='CHW', W=99)
# Pandas(Index=774, Team='CIN', W=74)
# Pandas(Index=775, Team='CLE', W=70)
# Pandas(Index=776, Team='DET', W=92)
# Pandas(Index=777, Team='HOU', W=85)
# Pandas(Index=778, Team='KCR', W=79)
# Pandas(Index=779, Team='LAD', W=91)
# Pandas(Index=780, Team='MIL', W=87)
# Pandas(Index=781, Team='MIN', W=70)
# Pandas(Index=782, Team='MON', W=82)
# Pandas(Index=783, Team='NYM', W=68)
# Pandas(Index=784, Team='NYY', W=91)
# Pandas(Index=785, Team='OAK', W=74)
# Pandas(Index=786, Team='PHI', W=90)
# Pandas(Index=787, Team='PIT', W=84)
# Pandas(Index=788, Team='SDP', W=81)
# Pandas(Index=789, Team='SEA', W=60)
# Pandas(Index=790, Team='SFG', W=79)
# Pandas(Index=791, Team='STL', W=79)
# Pandas(Index=792, Team='TEX', W=77)
# Pandas(Index=793, Team='TOR', W=89)
# Pandas(Index=794, Team='ATL', W=89)
# Pandas(Index=795, Team='BAL', W=94)
# Pandas(Index=796, Team='BOS', W=89)
# Pandas(Index=797, Team='CAL', W=93)
# Pandas(Index=798, Team='CHC', W=73)
# Pandas(Index=799, Team='CHW', W=87)
# Pandas(Index=800, Team='CIN', W=61)
# Pandas(Index=801, Team='CLE', W=78)
# Pandas(Index=802, Team='DET', W=83)
# Pandas(Index=803, Team='HOU', W=77)
# Pandas(Index=804, Team='KCR', W=90)
# Pandas(Index=805, Team='LAD', W=88)
# Pandas(Index=806, Team='MIL', W=95)
# Pandas(Index=807, Team='MIN', W=60)
# Pandas(Index=808, Team='MON', W=86)
# Pandas(Index=809, Team='NYM', W=65)
# Pandas(Index=810, Team='NYY', W=79)
# Pandas(Index=811, Team='OAK', W=68)
# Pandas(Index=812, Team='PHI', W=89)
# Pandas(Index=813, Team='PIT', W=84)
# Pandas(Index=814, Team='SDP', W=81)
# Pandas(Index=815, Team='SEA', W=76)
# Pandas(Index=816, Team='SFG', W=87)
# Pandas(Index=817, Team='STL', W=92)
# Pandas(Index=818, Team='TEX', W=64)
# Pandas(Index=819, Team='TOR', W=78)
# Pandas(Index=820, Team='ATL', W=81)
# Pandas(Index=821, Team='BAL', W=100)
# Pandas(Index=822, Team='BOS', W=83)
# Pandas(Index=823, Team='CAL', W=65)
# Pandas(Index=824, Team='CHC', W=64)
# Pandas(Index=825, Team='CHW', W=70)
# Pandas(Index=826, Team='CIN', W=89)
# Pandas(Index=827, Team='CLE', W=79)
# Pandas(Index=828, Team='DET', W=84)
# Pandas(Index=829, Team='HOU', W=93)
# Pandas(Index=830, Team='KCR', W=97)
# Pandas(Index=831, Team='LAD', W=92)
# Pandas(Index=832, Team='MIL', W=86)
# Pandas(Index=833, Team='MIN', W=77)
# Pandas(Index=834, Team='MON', W=90)
# Pandas(Index=835, Team='NYM', W=67)
# Pandas(Index=836, Team='NYY', W=103)
# Pandas(Index=837, Team='OAK', W=83)
# Pandas(Index=838, Team='PHI', W=91)
# Pandas(Index=839, Team='PIT', W=83)
# Pandas(Index=840, Team='SDP', W=73)
# Pandas(Index=841, Team='SEA', W=59)
# Pandas(Index=842, Team='SFG', W=75)
# Pandas(Index=843, Team='STL', W=74)
# Pandas(Index=844, Team='TEX', W=76)
# Pandas(Index=845, Team='TOR', W=67)
# Pandas(Index=846, Team='ATL', W=66)
# Pandas(Index=847, Team='BAL', W=102)
# Pandas(Index=848, Team='BOS', W=91)
# Pandas(Index=849, Team='CAL', W=88)
# Pandas(Index=850, Team='CHC', W=80)
# Pandas(Index=851, Team='CHW', W=73)
# Pandas(Index=852, Team='CIN', W=90)
# Pandas(Index=853, Team='CLE', W=81)
# Pandas(Index=854, Team='DET', W=84)
# Pandas(Index=855, Team='HOU', W=89)
# Pandas(Index=856, Team='KCR', W=85)
# Pandas(Index=857, Team='LAD', W=79)
# Pandas(Index=858, Team='MIL', W=95)
# Pandas(Index=859, Team='MIN', W=82)
# Pandas(Index=860, Team='MON', W=95)
# Pandas(Index=861, Team='NYM', W=63)
# Pandas(Index=862, Team='NYY', W=89)
# Pandas(Index=863, Team='OAK', W=54)
# Pandas(Index=864, Team='PHI', W=84)
# Pandas(Index=865, Team='PIT', W=98)
# Pandas(Index=866, Team='SDP', W=68)
# Pandas(Index=867, Team='SEA', W=67)
# Pandas(Index=868, Team='SFG', W=71)
# Pandas(Index=869, Team='STL', W=86)
# Pandas(Index=870, Team='TEX', W=83)
# Pandas(Index=871, Team='TOR', W=53)
# Pandas(Index=872, Team='ATL', W=69)
# Pandas(Index=873, Team='BAL', W=90)
# Pandas(Index=874, Team='BOS', W=99)
# Pandas(Index=875, Team='CAL', W=87)
# Pandas(Index=876, Team='CHC', W=79)
# Pandas(Index=877, Team='CHW', W=71)
# Pandas(Index=878, Team='CIN', W=92)
# Pandas(Index=879, Team='CLE', W=69)
# Pandas(Index=880, Team='DET', W=86)
# Pandas(Index=881, Team='HOU', W=74)
# Pandas(Index=882, Team='KCR', W=92)
# Pandas(Index=883, Team='LAD', W=95)
# Pandas(Index=884, Team='MIL', W=93)
# Pandas(Index=885, Team='MIN', W=73)
# Pandas(Index=886, Team='MON', W=76)
# Pandas(Index=887, Team='NYM', W=66)
# Pandas(Index=888, Team='NYY', W=100)
# Pandas(Index=889, Team='OAK', W=69)
# Pandas(Index=890, Team='PHI', W=90)
# Pandas(Index=891, Team='PIT', W=88)
# Pandas(Index=892, Team='SDP', W=84)
# Pandas(Index=893, Team='SEA', W=56)
# Pandas(Index=894, Team='SFG', W=89)
# Pandas(Index=895, Team='STL', W=69)
# Pandas(Index=896, Team='TEX', W=87)
# Pandas(Index=897, Team='TOR', W=59)
# Pandas(Index=898, Team='ATL', W=61)
# Pandas(Index=899, Team='BAL', W=97)
# Pandas(Index=900, Team='BOS', W=97)
# Pandas(Index=901, Team='CAL', W=74)
# Pandas(Index=902, Team='CHC', W=81)
# Pandas(Index=903, Team='CHW', W=90)
# Pandas(Index=904, Team='CIN', W=88)
# Pandas(Index=905, Team='CLE', W=71)
# Pandas(Index=906, Team='DET', W=74)
# Pandas(Index=907, Team='HOU', W=81)
# Pandas(Index=908, Team='KCR', W=102)
# Pandas(Index=909, Team='LAD', W=98)
# Pandas(Index=910, Team='MIL', W=67)
# Pandas(Index=911, Team='MIN', W=84)
# Pandas(Index=912, Team='MON', W=75)
# Pandas(Index=913, Team='NYM', W=64)
# Pandas(Index=914, Team='NYY', W=100)
# Pandas(Index=915, Team='OAK', W=63)
# Pandas(Index=916, Team='PHI', W=101)
# Pandas(Index=917, Team='PIT', W=96)
# Pandas(Index=918, Team='SDP', W=69)
# Pandas(Index=919, Team='SEA', W=64)
# Pandas(Index=920, Team='SFG', W=75)
# Pandas(Index=921, Team='STL', W=83)
# Pandas(Index=922, Team='TEX', W=94)
# Pandas(Index=923, Team='TOR', W=54)
# Pandas(Index=924, Team='ATL', W=70)
# Pandas(Index=925, Team='BAL', W=88)
# Pandas(Index=926, Team='BOS', W=83)
# Pandas(Index=927, Team='CAL', W=76)
# Pandas(Index=928, Team='CHC', W=75)
# Pandas(Index=929, Team='CHW', W=64)
# Pandas(Index=930, Team='CIN', W=102)
# Pandas(Index=931, Team='CLE', W=81)
# Pandas(Index=932, Team='DET', W=74)
# Pandas(Index=933, Team='HOU', W=80)
# Pandas(Index=934, Team='KCR', W=90)
# Pandas(Index=935, Team='LAD', W=92)
# Pandas(Index=936, Team='MIL', W=66)
# Pandas(Index=937, Team='MIN', W=85)
# Pandas(Index=938, Team='MON', W=55)
# Pandas(Index=939, Team='NYM', W=86)
# Pandas(Index=940, Team='NYY', W=97)
# Pandas(Index=941, Team='OAK', W=87)
# Pandas(Index=942, Team='PHI', W=101)
# Pandas(Index=943, Team='PIT', W=92)
# Pandas(Index=944, Team='SDP', W=73)
# Pandas(Index=945, Team='SFG', W=74)
# Pandas(Index=946, Team='STL', W=72)
# Pandas(Index=947, Team='TEX', W=76)
# Pandas(Index=948, Team='ATL', W=67)
# Pandas(Index=949, Team='BAL', W=90)
# Pandas(Index=950, Team='BOS', W=95)
# Pandas(Index=951, Team='CAL', W=72)
# Pandas(Index=952, Team='CHC', W=75)
# Pandas(Index=953, Team='CHW', W=75)
# Pandas(Index=954, Team='CIN', W=108)
# Pandas(Index=955, Team='CLE', W=79)
# Pandas(Index=956, Team='DET', W=57)
# Pandas(Index=957, Team='HOU', W=64)
# Pandas(Index=958, Team='KCR', W=91)
# Pandas(Index=959, Team='LAD', W=88)
# Pandas(Index=960, Team='MIL', W=68)
# Pandas(Index=961, Team='MIN', W=76)
# Pandas(Index=962, Team='MON', W=75)
# Pandas(Index=963, Team='NYM', W=82)
# Pandas(Index=964, Team='NYY', W=83)
# Pandas(Index=965, Team='OAK', W=98)
# Pandas(Index=966, Team='PHI', W=86)
# Pandas(Index=967, Team='PIT', W=92)
# Pandas(Index=968, Team='SDP', W=71)
# Pandas(Index=969, Team='SFG', W=80)
# Pandas(Index=970, Team='STL', W=82)
# Pandas(Index=971, Team='TEX', W=79)
# Pandas(Index=972, Team='ATL', W=88)
# Pandas(Index=973, Team='BAL', W=91)
# Pandas(Index=974, Team='BOS', W=84)
# Pandas(Index=975, Team='CAL', W=68)
# Pandas(Index=976, Team='CHC', W=66)
# Pandas(Index=977, Team='CHW', W=80)
# Pandas(Index=978, Team='CIN', W=98)
# Pandas(Index=979, Team='CLE', W=77)
# Pandas(Index=980, Team='DET', W=72)
# Pandas(Index=981, Team='HOU', W=81)
# Pandas(Index=982, Team='KCR', W=77)
# Pandas(Index=983, Team='LAD', W=102)
# Pandas(Index=984, Team='MIL', W=76)
# Pandas(Index=985, Team='MIN', W=82)
# Pandas(Index=986, Team='MON', W=79)
# Pandas(Index=987, Team='NYM', W=71)
# Pandas(Index=988, Team='NYY', W=89)
# Pandas(Index=989, Team='OAK', W=90)
# Pandas(Index=990, Team='PHI', W=80)
# Pandas(Index=991, Team='PIT', W=88)
# Pandas(Index=992, Team='SDP', W=60)
# Pandas(Index=993, Team='SFG', W=72)
# Pandas(Index=994, Team='STL', W=86)
# Pandas(Index=995, Team='TEX', W=83)
# Pandas(Index=996, Team='ATL', W=76)
# Pandas(Index=997, Team='BAL', W=97)
# Pandas(Index=998, Team='BOS', W=89)
# Pandas(Index=999, Team='CAL', W=79)
# Pandas(Index=1000, Team='CHC', W=77)
# Pandas(Index=1001, Team='CHW', W=77)
# Pandas(Index=1002, Team='CIN', W=99)
# Pandas(Index=1003, Team='CLE', W=71)
# Pandas(Index=1004, Team='DET', W=85)
# Pandas(Index=1005, Team='HOU', W=82)
# Pandas(Index=1006, Team='KCR', W=88)
# Pandas(Index=1007, Team='LAD', W=95)
# Pandas(Index=1008, Team='MIL', W=74)
# Pandas(Index=1009, Team='MIN', W=81)
# Pandas(Index=1010, Team='MON', W=79)
# Pandas(Index=1011, Team='NYM', W=82)
# Pandas(Index=1012, Team='NYY', W=80)
# Pandas(Index=1013, Team='OAK', W=94)
# Pandas(Index=1014, Team='PHI', W=71)
# Pandas(Index=1015, Team='PIT', W=80)
# Pandas(Index=1016, Team='SDP', W=60)
# Pandas(Index=1017, Team='SFG', W=88)
# Pandas(Index=1018, Team='STL', W=81)
# Pandas(Index=1019, Team='TEX', W=57)
# Pandas(Index=1020, Team='ATL', W=82)
# Pandas(Index=1021, Team='BAL', W=101)
# Pandas(Index=1022, Team='BOS', W=85)
# Pandas(Index=1023, Team='CAL', W=76)
# Pandas(Index=1024, Team='CHC', W=83)
# Pandas(Index=1025, Team='CHW', W=79)
# Pandas(Index=1026, Team='CIN', W=79)
# Pandas(Index=1027, Team='CLE', W=60)
# Pandas(Index=1028, Team='DET', W=91)
# Pandas(Index=1029, Team='HOU', W=79)
# Pandas(Index=1030, Team='KCR', W=85)
# Pandas(Index=1031, Team='LAD', W=89)
# Pandas(Index=1032, Team='MIL', W=69)
# Pandas(Index=1033, Team='MIN', W=74)
# Pandas(Index=1034, Team='MON', W=71)
# Pandas(Index=1035, Team='NYM', W=83)
# Pandas(Index=1036, Team='NYY', W=81)
# Pandas(Index=1037, Team='OAK', W=101)
# Pandas(Index=1038, Team='PHI', W=67)
# Pandas(Index=1039, Team='PIT', W=97)
# Pandas(Index=1040, Team='SDP', W=61)
# Pandas(Index=1041, Team='SFG', W=90)
# Pandas(Index=1042, Team='STL', W=90)
# Pandas(Index=1043, Team='WSA', W=63)
# Pandas(Index=1044, Team='ATL', W=76)
# Pandas(Index=1045, Team='BAL', W=108)
# Pandas(Index=1046, Team='BOS', W=87)
# Pandas(Index=1047, Team='CAL', W=86)
# Pandas(Index=1048, Team='CHC', W=84)
# Pandas(Index=1049, Team='CHW', W=56)
# Pandas(Index=1050, Team='CIN', W=102)
# Pandas(Index=1051, Team='CLE', W=76)
# Pandas(Index=1052, Team='DET', W=79)
# Pandas(Index=1053, Team='HOU', W=79)
# Pandas(Index=1054, Team='KCR', W=65)
# Pandas(Index=1055, Team='LAD', W=87)
# Pandas(Index=1056, Team='MIL', W=65)
# Pandas(Index=1057, Team='MIN', W=98)
# Pandas(Index=1058, Team='MON', W=73)
# Pandas(Index=1059, Team='NYM', W=83)
# Pandas(Index=1060, Team='NYY', W=93)
# Pandas(Index=1061, Team='OAK', W=89)
# Pandas(Index=1062, Team='PHI', W=73)
# Pandas(Index=1063, Team='PIT', W=89)
# Pandas(Index=1064, Team='SDP', W=63)
# Pandas(Index=1065, Team='SFG', W=86)
# Pandas(Index=1066, Team='STL', W=76)
# Pandas(Index=1067, Team='WSA', W=70)
# Pandas(Index=1068, Team='ATL', W=93)
# Pandas(Index=1069, Team='BAL', W=109)
# Pandas(Index=1070, Team='BOS', W=87)
# Pandas(Index=1071, Team='CAL', W=71)
# Pandas(Index=1072, Team='CHC', W=92)
# Pandas(Index=1073, Team='CHW', W=68)
# Pandas(Index=1074, Team='CIN', W=89)
# Pandas(Index=1075, Team='CLE', W=62)
# Pandas(Index=1076, Team='DET', W=90)
# Pandas(Index=1077, Team='HOU', W=81)
# Pandas(Index=1078, Team='KCR', W=69)
# Pandas(Index=1079, Team='LAD', W=85)
# Pandas(Index=1080, Team='MIN', W=97)
# Pandas(Index=1081, Team='MON', W=52)
# Pandas(Index=1082, Team='NYM', W=100)
# Pandas(Index=1083, Team='NYY', W=80)
# Pandas(Index=1084, Team='OAK', W=88)
# Pandas(Index=1085, Team='PHI', W=63)
# Pandas(Index=1086, Team='PIT', W=88)
# Pandas(Index=1087, Team='SDP', W=52)
# Pandas(Index=1088, Team='SEP', W=64)
# Pandas(Index=1089, Team='SFG', W=90)
# Pandas(Index=1090, Team='STL', W=87)
# Pandas(Index=1091, Team='WSA', W=86)
# Pandas(Index=1092, Team='ATL', W=81)
# Pandas(Index=1093, Team='BAL', W=91)
# Pandas(Index=1094, Team='BOS', W=86)
# Pandas(Index=1095, Team='CAL', W=67)
# Pandas(Index=1096, Team='CHC', W=84)
# Pandas(Index=1097, Team='CHW', W=67)
# Pandas(Index=1098, Team='CIN', W=83)
# Pandas(Index=1099, Team='CLE', W=86)
# Pandas(Index=1100, Team='DET', W=103)
# Pandas(Index=1101, Team='HOU', W=72)
# Pandas(Index=1102, Team='LAD', W=76)
# Pandas(Index=1103, Team='MIN', W=79)
# Pandas(Index=1104, Team='NYM', W=73)
# Pandas(Index=1105, Team='NYY', W=83)
# Pandas(Index=1106, Team='OAK', W=82)
# Pandas(Index=1107, Team='PHI', W=76)
# Pandas(Index=1108, Team='PIT', W=80)
# Pandas(Index=1109, Team='SFG', W=88)
# Pandas(Index=1110, Team='STL', W=97)
# Pandas(Index=1111, Team='WSA', W=65)
# Pandas(Index=1112, Team='ATL', W=77)
# Pandas(Index=1113, Team='BAL', W=76)
# Pandas(Index=1114, Team='BOS', W=92)
# Pandas(Index=1115, Team='CAL', W=84)
# Pandas(Index=1116, Team='CHC', W=87)
# Pandas(Index=1117, Team='CHW', W=89)
# Pandas(Index=1118, Team='CIN', W=87)
# Pandas(Index=1119, Team='CLE', W=75)
# Pandas(Index=1120, Team='DET', W=91)
# Pandas(Index=1121, Team='HOU', W=69)
# Pandas(Index=1122, Team='KCA', W=62)
# Pandas(Index=1123, Team='LAD', W=73)
# Pandas(Index=1124, Team='MIN', W=91)
# Pandas(Index=1125, Team='NYM', W=61)
# Pandas(Index=1126, Team='NYY', W=72)
# Pandas(Index=1127, Team='PHI', W=82)
# Pandas(Index=1128, Team='PIT', W=81)
# Pandas(Index=1129, Team='SFG', W=91)
# Pandas(Index=1130, Team='STL', W=101)
# Pandas(Index=1131, Team='WSA', W=76)
# Pandas(Index=1132, Team='ATL', W=85)
# Pandas(Index=1133, Team='BAL', W=97)
# Pandas(Index=1134, Team='BOS', W=72)
# Pandas(Index=1135, Team='CAL', W=80)
# Pandas(Index=1136, Team='CHC', W=59)
# Pandas(Index=1137, Team='CHW', W=83)
# Pandas(Index=1138, Team='CIN', W=76)
# Pandas(Index=1139, Team='CLE', W=81)
# Pandas(Index=1140, Team='DET', W=88)
# Pandas(Index=1141, Team='HOU', W=72)
# Pandas(Index=1142, Team='KCA', W=74)
# Pandas(Index=1143, Team='LAD', W=95)
# Pandas(Index=1144, Team='MIN', W=89)
# Pandas(Index=1145, Team='NYM', W=66)
# Pandas(Index=1146, Team='NYY', W=70)
# Pandas(Index=1147, Team='PHI', W=87)
# Pandas(Index=1148, Team='PIT', W=92)
# Pandas(Index=1149, Team='SFG', W=93)
# Pandas(Index=1150, Team='STL', W=83)
# Pandas(Index=1151, Team='WSA', W=71)
# Pandas(Index=1152, Team='BAL', W=94)
# Pandas(Index=1153, Team='BOS', W=62)
# Pandas(Index=1154, Team='CAL', W=75)
# Pandas(Index=1155, Team='CHC', W=72)
# Pandas(Index=1156, Team='CHW', W=95)
# Pandas(Index=1157, Team='CIN', W=89)
# Pandas(Index=1158, Team='CLE', W=87)
# Pandas(Index=1159, Team='DET', W=89)
# Pandas(Index=1160, Team='HOU', W=65)
# Pandas(Index=1161, Team='KCA', W=59)
# Pandas(Index=1162, Team='LAD', W=97)
# Pandas(Index=1163, Team='MIN', W=102)
# Pandas(Index=1164, Team='MLN', W=86)
# Pandas(Index=1165, Team='NYM', W=50)
# Pandas(Index=1166, Team='NYY', W=77)
# Pandas(Index=1167, Team='PHI', W=85)
# Pandas(Index=1168, Team='PIT', W=90)
# Pandas(Index=1169, Team='SFG', W=95)
# Pandas(Index=1170, Team='STL', W=80)
# Pandas(Index=1171, Team='WSA', W=70)
# Pandas(Index=1172, Team='BAL', W=97)
# Pandas(Index=1173, Team='BOS', W=72)
# Pandas(Index=1174, Team='CHC', W=76)
# Pandas(Index=1175, Team='CHW', W=98)
# Pandas(Index=1176, Team='CIN', W=92)
# Pandas(Index=1177, Team='CLE', W=79)
# Pandas(Index=1178, Team='DET', W=85)
# Pandas(Index=1179, Team='HOU', W=66)
# Pandas(Index=1180, Team='KCA', W=57)
# Pandas(Index=1181, Team='LAA', W=82)
# Pandas(Index=1182, Team='LAD', W=80)
# Pandas(Index=1183, Team='MIN', W=79)
# Pandas(Index=1184, Team='MLN', W=88)
# Pandas(Index=1185, Team='NYM', W=53)
# Pandas(Index=1186, Team='NYY', W=99)
# Pandas(Index=1187, Team='PHI', W=92)
# Pandas(Index=1188, Team='PIT', W=80)
# Pandas(Index=1189, Team='SFG', W=90)
# Pandas(Index=1190, Team='STL', W=93)
# Pandas(Index=1191, Team='WSA', W=62)
# Pandas(Index=1192, Team='BAL', W=86)
# Pandas(Index=1193, Team='BOS', W=76)
# Pandas(Index=1194, Team='CHC', W=82)
# Pandas(Index=1195, Team='CHW', W=94)
# Pandas(Index=1196, Team='CIN', W=86)
# Pandas(Index=1197, Team='CLE', W=79)
# Pandas(Index=1198, Team='DET', W=79)
# Pandas(Index=1199, Team='HOU', W=66)
# Pandas(Index=1200, Team='KCA', W=73)
# Pandas(Index=1201, Team='LAA', W=70)
# Pandas(Index=1202, Team='LAD', W=99)
# Pandas(Index=1203, Team='MIN', W=91)
# Pandas(Index=1204, Team='MLN', W=84)
# Pandas(Index=1205, Team='NYM', W=51)
# Pandas(Index=1206, Team='NYY', W=104)
# Pandas(Index=1207, Team='PHI', W=87)
# Pandas(Index=1208, Team='PIT', W=74)
# Pandas(Index=1209, Team='SFG', W=88)
# Pandas(Index=1210, Team='STL', W=93)
# Pandas(Index=1211, Team='WSA', W=56)
# Pandas(Index=1212, Team='BAL', W=77)
# Pandas(Index=1213, Team='BOS', W=76)
# Pandas(Index=1214, Team='CHC', W=59)
# Pandas(Index=1215, Team='CHW', W=85)
# Pandas(Index=1216, Team='CIN', W=98)
# Pandas(Index=1217, Team='CLE', W=80)
# Pandas(Index=1218, Team='DET', W=85)
# Pandas(Index=1219, Team='HOU', W=64)
# Pandas(Index=1220, Team='KCA', W=72)
# Pandas(Index=1221, Team='LAA', W=86)
# Pandas(Index=1222, Team='LAD', W=102)
# Pandas(Index=1223, Team='MIN', W=91)
# Pandas(Index=1224, Team='MLN', W=86)
# Pandas(Index=1225, Team='NYM', W=40)
# Pandas(Index=1226, Team='NYY', W=96)
# Pandas(Index=1227, Team='PHI', W=81)
# Pandas(Index=1228, Team='PIT', W=93)
# Pandas(Index=1229, Team='SFG', W=103)
# Pandas(Index=1230, Team='STL', W=84)
# Pandas(Index=1231, Team='WSA', W=60)
