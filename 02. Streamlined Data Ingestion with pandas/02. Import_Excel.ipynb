# %% [markdown]
# ## **Librerias**

# %%
import pandas as pd

# %%
pd.options.display.max_columns = False

# %% [markdown]
# ## **Datos**

# %% [markdown]
# ### 1. Llamando a los datos

# %%
survey_data = pd.read_excel(
    'fcc-new-coder-survey.xlsx',
    skiprows=2
)

# %%
survey_data.head(2)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  28.0               0.0             NaN                NaN          NaN
# 1  22.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN  between 100,000 and 1 million
# 1                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# 0                   NaN                   NaN  ...                  NaN
# 1                   NaN                   NaN  ...                  NaN
#
#    ResourceSkillCrush  ResourceStackOverflow  ResourceTreehouse  \
# 0                 NaN                    NaN                NaN
# 1                 NaN                    NaN                NaN
#
#    ResourceUdacity  ResourceUdemy  ResourceW3Schools  \
# 0              NaN            NaN                NaN
# ...

# %%
survey_data.head(2)
# Out:
#     Age  AttendedBootcamp  ...  SchoolMajor  StudentDebtOwe
# 0  28.0               0.0  ...          NaN           20000
# 1  22.0               0.0  ...          NaN             NaN
#
# [2 rows x 98 columns]

# %%
survey_dataV2 = pd.read_excel(
    'fcc-new-coder-survey.xlsx',
    skiprows = 2,
    usecols = 'W:AB, AR' #Esto se refiero a la columna del excel original
)

survey_dataV2.head()
# Out:
#    CommuteTime            CountryCitizen  ...    EmploymentStatus   Income
# 0         35.0  United States of America  ...  Employed for wages  32000.0
# 1         90.0  United States of America  ...  Employed for wages  15000.0
# 2         45.0  United States of America  ...  Employed for wages  48000.0
# 3         45.0  United States of America  ...  Employed for wages  43000.0
# 4         10.0  United States of America  ...  Employed for wages   6000.0
#
# [5 rows x 7 columns]

# %% [markdown]
# ### 2. Llamando datos de multiples worksheets

# %%
survey_dataV3 = pd.read_excel(
    'fcc-new-coder-survey.xlsx',
    skiprows = 2,
    sheet_name = 1
)

survey_dataV3.head(2)
# Out:
#     Age  AttendedBootcamp  ...  SchoolMajor  StudentDebtOwe
# 0  27.0               0.0  ...          NaN             NaN
# 1  34.0               0.0  ...          NaN             NaN
#
# [2 rows x 98 columns]

# %%
len(survey_dataV3)
# Out:
# 1000

# %%
survey_dataV4 = pd.read_excel(
    'fcc-new-coder-survey.xlsx',
    skiprows=2,
    sheet_name = None
)

# %%
all_responses = pd.DataFrame()

for sheet_name, frame in survey_dataV4.items():
    frame['Year'] = sheet_name
    
    all_responses = all_responses.append(frame)
